# %% [markdown]
# # Data-5 Team-2
# ## Week-4, Task-2

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from afinn import Afinn

# %% [markdown]
# importing the data

# %%
df1 = pd.read_csv("../Week 1/exported_data/googleplaystore_clean.csv")
df1
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9655                                   Sya9a Maroc - FR               FAMILY
# 9656                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9657                             Parkinson Exercices FR              MEDICAL
# 9658                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9659      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df2 = pd.read_csv("muhammed_exported/reviews_with_scores.csv")
df2
# Out:
#        Unnamed: 0                          App  \
# 0               0        10 Best Foods for You
# 1               1        10 Best Foods for You
# 2               2        10 Best Foods for You
# 3               3        10 Best Foods for You
# 4               4        10 Best Foods for You
# ...           ...                          ...
# 64290       64290  Houzz Interior Design Ideas
# 64291       64291  Houzz Interior Design Ideas
# 64292       64292  Houzz Interior Design Ideas
# 64293       64293  Houzz Interior Design Ideas
# 64294       64294  Houzz Interior Design Ideas
#
#                                        Translated_Review  affin_scores  \
# 0      I like eat delicious food. That's I'm cooking ...          13.0
# 1        This help eating healthy exercise regular basis           4.0
# 2                                                                  0.0
# 3             Works great especially going grocery store           3.0
# ...

# %%
df = pd.merge(df1, df2, how='inner', on="App")
df =  df.drop(labels='Unnamed: 0', axis=1)
df
# Out:
#                                 App        Category  Rating  Reviews  \
# 0               Coloring book moana  ART_AND_DESIGN     3.9      967
# 1               Coloring book moana  ART_AND_DESIGN     3.9      967
# 2               Coloring book moana  ART_AND_DESIGN     3.9      967
# 3               Coloring book moana  ART_AND_DESIGN     3.9      967
# 4               Coloring book moana  ART_AND_DESIGN     3.9      967
# ...                             ...             ...     ...      ...
# 61551  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 61552  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 61553  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 61554  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
# 61555  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5   223941
#
#                      Size  Installs  Type  Price Content_Rating  \
# 0                    14.0    500000  Free    0.0       Everyone
# ...

# %%
df_copy_top = df[df["Type"] != "Free"].drop_duplicates().sort_values(by=["affin_scores"], ascending=False).reset_index(drop=True).iloc[:5,:]
df_copy_top
# Out:
#                             App         Category  Rating  Reviews  Size  \
# 0  Dr. Panda & Toto's Treehouse           FAMILY     4.4     3396   9.5
# 1           Essential Anatomy 3          MEDICAL     4.1     1533  42.0
# 2         Beautiful Widgets Pro  PERSONALIZATION     4.2    97890  14.0
# 3       Golfshot Plus: Golf GPS           SPORTS     4.1     3387  25.0
# 4                    HD Widgets  PERSONALIZATION     4.3    58617  26.0
#
#    Installs  Type  Price Content_Rating  \
# 0     50000  Paid   3.99       Everyone
# 1     50000  Paid  11.99     Mature 17+
# 2   1000000  Paid   2.49       Everyone
# 3     50000  Paid  29.99       Everyone
# 4   1000000  Paid   0.99       Everyone
#
#                                    Translated_Review  affin_scores  np_scores
# 0  I love I love I love I love love love I like c...          39.0         14
# 1  Amazing backed excellent tech support team! Th...          23.0          4
# ...

# %%
df_copy_worse = df[df["Type"] != "Free"].drop_duplicates().sort_values(by=["affin_scores"]).reset_index(drop=True).iloc[:5,:]
df_copy_worse
# Out:
#                               App         Category  Rating  Reviews  Size  \
# 0                    BIG Launcher  PERSONALIZATION     4.3      881   5.9
# 1           Beautiful Widgets Pro  PERSONALIZATION     4.2    97890  14.0
# 2           Beautiful Widgets Pro  PERSONALIZATION     4.2    97890  14.0
# 3                      HD Widgets  PERSONALIZATION     4.3    58617  26.0
# 4  Call of Duty:Black Ops Zombies             GAME     4.2    13004  46.0
#
#    Installs  Type  Price Content_Rating  \
# 0     10000  Paid   9.99       Everyone
# 1   1000000  Paid   2.49       Everyone
# 2   1000000  Paid   2.49       Everyone
# 3   1000000  Paid   0.99       Everyone
# 4    100000  Paid   6.99           Teen
#
#                                    Translated_Review  affin_scores  np_scores
# 0  Very disappointed discover purchase serious fl...         -10.0         -4
# 1  Still work Not sure main features work? It upd...          -6.0         -1
# ...
