# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Week 1/exported_data/googleplaystore_clean.csv")
df
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9655                                   Sya9a Maroc - FR               FAMILY
# 9656                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9657                             Parkinson Exercices FR              MEDICAL
# 9658                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9659      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_installs = df.groupby("Category")["Installs"].sum().sort_values(ascending=False).to_frame()
high_score = 33 * -1
df_installs['Score_1'] = range(high_score, len(df_installs) + high_score)
df_installs['Score_1'] = df_installs['Score_1'] * (-1)
df_installs
# Out:
#                         Installs  Score_1
# Category
# GAME                 13878924415       33
# COMMUNICATION        11038276251       32
# TOOLS                 8001772915       31
# PRODUCTIVITY          5793091369       30
# SOCIAL                5487867902       29
# PHOTOGRAPHY           4649147655       28
# FAMILY                4427941505       27
# VIDEO_PLAYERS         3926902720       26
# TRAVEL_AND_LOCAL      2894887146       25
# NEWS_AND_MAGAZINES    2369217760       24
# ENTERTAINMENT         2113660000       23
# BOOKS_AND_REFERENCE   1665969576       22
# PERSONALIZATION       1532494782       21
# SHOPPING              1400348785       20
# HEALTH_AND_FITNESS    1144022512       19
# SPORTS                1096474498       18
# BUSINESS               697164865       17
# LIFESTYLE              503823539       16
# MAPS_AND_NAVIGATION    503281890       15
# FINANCE                455348734       14
# WEATHER                361100520       13
# ...

# %%
df_price = df.groupby("Category")["Price"].sum().sort_values(ascending=False).to_frame()
high_score = 33 * -1
df_price['Score_2'] = range(high_score, len(df_price) + high_score)
df_price['Score_2'] = df_price['Score_2'] * (-1)
df_price
# Out:
#                        Price  Score_2
# Category
# FINANCE              2900.83       33
# FAMILY               2399.86       32
# LIFESTYLE            2360.87       31
# MEDICAL               995.70       30
# GAME                  284.31       29
# TOOLS                 267.25       28
# PRODUCTIVITY          250.93       27
# BUSINESS              175.29       26
# PERSONALIZATION       150.48       25
# BOOKS_AND_REFERENCE   119.77       24
# PHOTOGRAPHY           118.28       23
# EVENTS                109.99       22
# SPORTS                100.00       21
# COMMUNICATION          83.14       20
# HEALTH_AND_FITNESS     64.35       19
# TRAVEL_AND_LOCAL       49.95       18
# WEATHER                32.42       17
# DATING                 27.44       16
# MAPS_AND_NAVIGATION    26.95       15
# EDUCATION              17.96       14
# SOCIAL                 15.97       13
# AUTO_AND_VEHICLES      13.47       12
# VIDEO_PLAYERS          10.46       11
# ...

# %%
df["Revenue"] = df["Installs"] * df["Price"]
df_revenue = df.groupby("Category")["Revenue"].sum().sort_values(ascending=False).to_frame()
high_score = 33 * -1
df_revenue['Score_3'] = range(high_score, len(df_revenue) + high_score)
df_revenue['Score_3'] = df_revenue['Score_3'] * (-1)
df_revenue
# Out:
#                           Revenue  Score_3
# Category
# FAMILY               1.136798e+08       33
# LIFESTYLE            5.758394e+07       32
# GAME                 4.068864e+07       31
# FINANCE              2.572668e+07       30
# PHOTOGRAPHY          8.547768e+06       29
# PERSONALIZATION      6.796948e+06       28
# MEDICAL              5.957536e+06       27
# TOOLS                5.464821e+06       26
# SPORTS               4.706212e+06       25
# PRODUCTIVITY         4.313375e+06       24
# COMMUNICATION        4.247364e+06       23
# WEATHER              4.181380e+06       22
# EDUCATION            2.403980e+06       21
# HEALTH_AND_FITNESS   1.426069e+06       20
# MAPS_AND_NAVIGATION  1.240789e+06       19
# TRAVEL_AND_LOCAL     1.151504e+06       18
# BUSINESS             1.050543e+06       17
# ENTERTAINMENT        7.980000e+05       16
# VIDEO_PLAYERS        3.352900e+05       15
# FOOD_AND_DRINK       2.844000e+05       14
# ...

# %%
df2 = pd.read_csv("../Week 4/Data/googleplaystore_user_reviews_clean_scores.csv")
df2 = df2.drop(labels='Unnamed: 0', axis=1)
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#    affin_score  np_score
# 0         13.0         4
# 1          4.0         1
# 2          0.0         0
# 3          3.0         2
# 4          3.0         1

# %%
df1 = pd.merge(df, df2, how='inner', on="App")
df1.head()
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0    500000  Free
#
#    Price Content_Rating  Revenue  \
# 0    0.0       Everyone      0.0
# 1    0.0       Everyone      0.0
# 2    0.0       Everyone      0.0
# 3    0.0       Everyone      0.0
# 4    0.0       Everyone      0.0
#
#                                    Translated_Review  affin_score  np_score
# 0  A kid's excessive ads. The types ads allowed a...         -2.0        -1
# 1                                         It bad >:(         -3.0        -1
# ...

# %%
df_sentiment = df1.groupby(['Category'])['affin_score'].sum().sort_values(ascending=False).reset_index(drop=False)
high_score = 33 * -1
df_sentiment['Score_4'] = range(high_score, len(df_sentiment) + high_score)
df_sentiment['Score_4'] = df_sentiment['Score_4'] * (-1)
df_sentiment
# Out:
#                Category  affin_score  Score_4
# 0                  GAME      22370.0       33
# 1    HEALTH_AND_FITNESS       8197.0       32
# 2                FAMILY       6118.0       31
# 3               MEDICAL       3915.0       30
# 4          PRODUCTIVITY       3896.0       29
# 5             EDUCATION       3388.0       28
# 6                DATING       3380.0       27
# 7                SPORTS       3147.0       26
# 8           PHOTOGRAPHY       3114.0       25
# 9      TRAVEL_AND_LOCAL       3077.0       24
# 10                TOOLS       2721.0       23
# 11      PERSONALIZATION       2672.0       22
# 12              FINANCE       2545.0       21
# 13            LIFESTYLE       2404.0       20
# 14             BUSINESS       2171.0       19
# 15             SHOPPING       2151.0       18
# 16        ENTERTAINMENT       2022.0       17
# 17        COMMUNICATION       1837.0       16
# 18       FOOD_AND_DRINK       1694.0       15
# ...

# %%
df_installs1 = df_installs.drop(labels='Installs', axis=1)
df_price1 = df_price.drop(labels='Price', axis=1)
df_revenue1 = df_revenue.drop(labels='Revenue', axis=1)
df_sentiment1 = df_sentiment.drop(labels='affin_score', axis=1)

# %%
df_scores = [df_installs1, df_price1, df_revenue1, df_sentiment1]
df_totalScore = pd.merge(df_installs1, df_price1, how="inner", on="Category")
df_totalScore
# Out:
#                      Score_1  Score_2
# Category
# GAME                      33       29
# COMMUNICATION             32       20
# TOOLS                     31       28
# PRODUCTIVITY              30       27
# SOCIAL                    29       13
# PHOTOGRAPHY               28       23
# FAMILY                    27       32
# VIDEO_PLAYERS             26       11
# TRAVEL_AND_LOCAL          25       18
# NEWS_AND_MAGAZINES        24        5
# ENTERTAINMENT             23        8
# BOOKS_AND_REFERENCE       22       24
# PERSONALIZATION           21       25
# SHOPPING                  20        6
# HEALTH_AND_FITNESS        19       19
# SPORTS                    18       21
# BUSINESS                  17       26
# LIFESTYLE                 16       31
# MAPS_AND_NAVIGATION       15       15
# FINANCE                   14       33
# WEATHER                   13       17
# EDUCATION                 12       14
# FOOD_AND_DRINK            11        9
# ...

# %%
#df_scores = [df_installs1, df_price1, df_revenue1, df_sentiment1]
df_totalScore = pd.merge(df_totalScore, df_revenue1, how="inner", on="Category")
df_totalScore
# Out:
#                      Score_1  Score_2  Score_3
# Category
# GAME                      33       29       31
# COMMUNICATION             32       20       23
# TOOLS                     31       28       26
# PRODUCTIVITY              30       27       24
# SOCIAL                    29       13        6
# PHOTOGRAPHY               28       23       29
# FAMILY                    27       32       33
# VIDEO_PLAYERS             26       11       15
# TRAVEL_AND_LOCAL          25       18       18
# NEWS_AND_MAGAZINES        24        5        7
# ENTERTAINMENT             23        8       16
# BOOKS_AND_REFERENCE       22       24       11
# PERSONALIZATION           21       25       28
# SHOPPING                  20        6        8
# HEALTH_AND_FITNESS        19       19       20
# SPORTS                    18       21       25
# BUSINESS                  17       26       17
# LIFESTYLE                 16       31       32
# MAPS_AND_NAVIGATION       15       15       19
# ...

# %%
#df_scores = [df_installs1, df_price1, df_revenue1, df_sentiment1]
df_totalScore = pd.merge(df_totalScore, df_sentiment1, how="inner", on="Category")
df_totalScore
# Out:
#                Category  Score_1  Score_2  Score_3  Score_4
# 0                  GAME       33       29       31       33
# 1         COMMUNICATION       32       20       23       16
# 2                 TOOLS       31       28       26       23
# 3          PRODUCTIVITY       30       27       24       29
# 4                SOCIAL       29       13        6        7
# 5           PHOTOGRAPHY       28       23       29       25
# 6                FAMILY       27       32       33       31
# 7         VIDEO_PLAYERS       26       11       15        5
# 8      TRAVEL_AND_LOCAL       25       18       18       24
# 9    NEWS_AND_MAGAZINES       24        5        7       13
# 10        ENTERTAINMENT       23        8       16       17
# 11  BOOKS_AND_REFERENCE       22       24       11       14
# 12      PERSONALIZATION       21       25       28       22
# 13             SHOPPING       20        6        8       18
# 14   HEALTH_AND_FITNESS       19       19       20       32
# ...

# %%
df_totalScore["Total_Score"] = df_totalScore["Score_1"]+df_totalScore["Score_2"]+df_totalScore["Score_3"]+df_totalScore["Score_4"]
df_totalScore = df_totalScore.sort_values(by="Total_Score", ascending=False).reset_index(drop=True)
df_totalScore.to_csv("total_scores.csv")
df_totalScore
# Out:
#                Category  Score_1  Score_2  Score_3  Score_4  Total_Score
# 0                  GAME       33       29       31       33          126
# 1                FAMILY       27       32       33       31          123
# 2          PRODUCTIVITY       30       27       24       29          110
# 3                 TOOLS       31       28       26       23          108
# 4           PHOTOGRAPHY       28       23       29       25          105
# 5             LIFESTYLE       16       31       32       20           99
# 6               FINANCE       14       33       30       21           98
# 7       PERSONALIZATION       21       25       28       22           96
# 8               MEDICAL        4       30       27       30           91
# 9         COMMUNICATION       32       20       23       16           91
# 10   HEALTH_AND_FITNESS       19       19       20       32           90
# 11               SPORTS       18       21       25       26           90
# ...

# %%
sns.set_style("ticks")
plt.figure(figsize=(16,6))
sns.barplot(x="Category", y="Total_Score", data=df_totalScore)
sns.set_context("talk", font_scale=0.7)
plt.title("Category Rankings According To Their Overall Score", fontsize=20)
plt.ylabel("Total Score", fontsize=20)
plt.xlabel("Categories", fontsize=20)
plt.xticks(rotation=90)   
plt.grid(color = 'black', alpha=0.1, linewidth = 2)
plt.show()
plt.clf()

# %%
sns.set_style("ticks")
plt.figure(figsize=(16,8))
sns.barplot(x="Total_Score", y="Category", data=df_totalScore, orient='horizontal')
sns.set_context("talk", font_scale=0.7)
plt.title("Category Rankings According To Their Overall Score", fontsize=20)
plt.ylabel("Categories", fontsize=20)
plt.xlabel("Total Score", fontsize=20)
#plt.xticks(rotation=0)   
plt.grid(color = 'black', alpha=0.1, linewidth = 2)
plt.show()
plt.clf()

# %%
df_sentiment.head()
# Out:
#              Category  affin_score  Score_4
# 0                GAME      22370.0       33
# 1  HEALTH_AND_FITNESS       8197.0       32
# 2              FAMILY       6118.0       31
# 3             MEDICAL       3915.0       30
# 4        PRODUCTIVITY       3896.0       29

# %%
sns.set_style("ticks")
plt.figure(figsize=(16,8))
sns.barplot(x="affin_score", y="Category", data=df_sentiment, orient='horizontal')
sns.set_context("talk", font_scale=0.7)
plt.title("Category Rankings According To Their Sentiment Score", fontsize=20)
plt.ylabel("Categories", fontsize=20)
plt.xlabel("Affin Score", fontsize=20) 
plt.grid(color = 'black', alpha=0.1, linewidth = 2)
plt.show()
plt.clf()
